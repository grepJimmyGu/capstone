# %%
import numpy as np

# %%
import panda
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-56b7b6cd50e2> in <module>()
# ----> 1 import panda
#
# ImportError: No module named panda
